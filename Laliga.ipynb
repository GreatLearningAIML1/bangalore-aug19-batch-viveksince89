# %%
import numpy as np
import pandas as pd

# %%
laliga= pd.read_csv("Laliga.csv")

# %%
Team=laliga.replace('-',0,inplace = False)

# %%
#did a split to get off the special characters
first = Team["Debut"].str.split("-",n=1,expand=True)

# %%
Team.insert(19,'Debuts',first[0])

# %%
Team["Debuts"]=Team["Debuts"].astype(int)

# %%
x=Team['Debuts']
for c in Team['Debuts']:
    if c>1929 and c<1980:
        print(c)
#with this I can print only the values which are true and not the corresponding Team column name.
#I got the answer but need to know how this will work
# Out:
# 1931
# 1934
# 1939
# 1932
# 1941
# 1939
# 1948
# 1944
# 1935
# 1949
# 1933
# 1960
# 1951
# 1941
# 1977
# 1959
# 1935
# 1961
# 1940
# 1930
# 1963
# 1974
# 1943
# 1977
# 1941
# 1962
# 1978
# 1971
# 1963
# 1947
# 1945
# 1953
# 1979
# 1950
# 1956
# 1951
# 1955

# %%
Team[(Team.Debuts>1929) & (Team.Debuts < 1980)].iloc[:,[1,20]]
# Out:
#                    Team  BestPosition
# 3              Valencia             1
# 5               Sevilla             1
# 8              Zaragoza             2
# 9            Real Betis             1
# 10  Deportivo La Coruna             1
# 11           Celta Vigo             4
# 12           Valladolid             4
# 14       Sporting Gijon             2
# 15              Osasuna             4
# 16               Malaga             4
# 17               Oviedo             3
# 18             Mallorca             3
# 19           Las Palmas             2
# 21              Granada             6
# 22       Rayo Vallecano             8
# 23                Elche             5
# 25             Hercules             5
# 26             Tenerife             5
# 27               Murcia            11
# 28               Alaves             6
# 29              Levante             6
# 30            Salamanca             7
# 31             Sabadell             4
# 32                Cadiz            12
# ...

# %%
#converted the object to int as it was giving error 
Team["Points"]=Team['Points'].astype(int)

# %%
Team.sort_values(["Points"],ascending=False).head()
# Out:
#    Pos             Team  Seasons  Points GamesPlayed GamesWon GamesDrawn  \
# 0    1      Real Madrid       86    4385        2762     1647        552
# 1    2        Barcelona       86    4262        2762     1581        573
# 2    3  Atletico Madrid       80    3442        2614     1241        598
# 3    4         Valencia       82    3386        2664     1187        616
# 4    5  Athletic Bilbao       86    3368        2762     1209        633
#
#   GamesLost GoalsFor GoalsAgainst  ... Runner-up Third Fourth Fifth Sixth   T  \
# 0       563     5947         3140  ...        23     8      8     3     4  79
# 1       608     5900         3114  ...        25    12     12     4     6  83
# 2       775     4534         3309  ...         8    16      9     7     6  56
# 3       861     4398         3469  ...         6    10     11    10     7  50
# 4       920     4631         3700  ...         7    10      5     8    10  49
#
#      Debut Since/LastApp Debuts  BestPosition
# ...

# %%
Team['GoalsFor']= Team['GoalsFor'].astype(int)
Team['GoalsAgainst']= Team['GoalsAgainst'].astype(int)

# %%
def Goal_diff_count():
    return Team['GoalsFor']-Team['GoalsAgainst']
Team['Goal_diff_count']=Goal_diff_count()

# %%
#not sure how to the corresponding Team, column value for the max value of Goal_diff_count
print(Team['Goal_diff_count'].max())
print(Team['Goal_diff_count'].min())
# Out:
# 2807
# -525

# %%
Team['GamesWon']=Team['GamesWon'].astype(int)
Team['GamesPlayed']=Team['GamesPlayed'].astype(int)

# %%
Percentage_of_Winning = (Team["GamesWon"]/Team["GamesPlayed"])*100

# %%
Team.insert(6,'Winning Percent',Percentage_of_Winning)

# %%
Team.fillna({"Winning Percent":'0%'})
# Out:
#     Pos                 Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0     1          Real Madrid       86    4385         2762      1647
# 1     2            Barcelona       86    4262         2762      1581
# 2     3      Atletico Madrid       80    3442         2614      1241
# 3     4             Valencia       82    3386         2664      1187
# 4     5      Athletic Bilbao       86    3368         2762      1209
# 5     6              Sevilla       73    2819         2408       990
# 6     7             Espanyol       82    2792         2626       948
# 7     8        Real Sociedad       70    2573         2302       864
# 8     9             Zaragoza       58    2109         1986       698
# 9    10           Real Betis       51    1884         1728       606
# 10   11  Deportivo La Coruna       45    1814         1530       563
# 11   12           Celta Vigo       51    1789         1698       586
# 12   13           Valladolid       42    1471         1466       463
# ...

# %%
Team.sort_values(['Winning Percent'],ascending=False).head()
# Out:
#    Pos             Team  Seasons  Points  GamesPlayed  GamesWon  \
# 0    1      Real Madrid       86    4385         2762      1647
# 1    2        Barcelona       86    4262         2762      1581
# 2    3  Atletico Madrid       80    3442         2614      1241
# 3    4         Valencia       82    3386         2664      1187
# 4    5  Athletic Bilbao       86    3368         2762      1209
#
#    Winning Percent GamesDrawn GamesLost  GoalsFor  ...  Third Fourth Fifth  \
# 0        59.630702        552       563      5947  ...      8      8     3
# 1        57.241130        573       608      5900  ...     12     12     4
# 2        47.475134        598       775      4534  ...     16      9     7
# 3        44.557057        616       861      4398  ...     10     11    10
# 4        43.772629        633       920      4631  ...     10      5     8
#
#   Sixth   T    Debut Since/LastApp Debuts BestPosition Goal_diff_count
# ...

# %%
Team.groupby('BestPosition').sum()
# Out:
#               Pos  Seasons  Points  GamesPlayed  GamesWon  Winning Percent  \
# BestPosition
# 1              50      659   27933        21532      9888       403.189019
# 2              79      195    6904         6614      2255       173.835110
# 3              89      154    5221         4936      1732       137.110098
# 4             125      191    6563         6497      2097       190.611137
# 5             115       63    1884         2082       624       119.694898
# 6             158       62    2113         2052       624       151.787752
# 7             190       38    1186         1335       382       143.726616
# 8             154       31    1134         1120       319       116.395766
# 9             107        4      96          114        26        22.807018
# 10            186       13     450          450       134       115.979532
# 11             28       18     445          586       145        24.744027
# ...
